# %%
import matplotlib.pyplot as plt
import numpy as np
from app.figures import Circle, Point
from app.utils import get_fig_base, calculate_area_monte_carlo
PI = np.pi

# %% [markdown]
# ## Draw some points

# %%
fig, ax =  get_fig_base()
o = Point('O', 0.5, 0.5)
circle = Circle(o, 0.5)
circle.draw(fig, ax, color='black', linewidth = 2)

# %%
calculate_area_monte_carlo(circle, 10, draw_final_result=True)
# Out:
# 0.9

# %%
# %%time
calculate_area_monte_carlo(circle, 100, draw_final_result=True)
# Out:
# CPU times: user 210 ms, sys: 3.82 ms, total: 214 ms
# Wall time: 213 ms
# 0.78

# %%
# %%time
calculate_area_monte_carlo(circle, 1000, draw_final_result=True)
# Out:
# CPU times: user 11.3 s, sys: 23.7 ms, total: 11.3 s
# Wall time: 11.3 s
# 0.798

# %%
# %%time
calculate_area_monte_carlo(circle, 10000, draw_final_result=False)
# Out:
# CPU times: user 89.5 ms, sys: 3.98 ms, total: 93.5 ms
# Wall time: 92.7 ms
# 0.7857

# %%
circle.get_area()
# Out:
# 0.7853981633974483

# %%
# %%time
calculate_area_monte_carlo(circle, int(1e5), draw_final_result=False)
# Out:
# CPU times: user 991 ms, sys: 20 ms, total: 1.01 s
# Wall time: 1.01 s
# 0.78588

# %%
# %%time
calculate_area_monte_carlo(circle, int(1e6), draw_final_result=False)
# Out:
# CPU times: user 10.1 s, sys: 92.2 ms, total: 10.2 s
# Wall time: 10.2 s
# 0.785573

# %%
# %%time
calculate_area_monte_carlo(circle, int(1e7), draw_final_result=False)
# Out:
# CPU times: user 1min 38s, sys: 1.4 s, total: 1min 39s
# Wall time: 1min 39s
# 0.7854297
