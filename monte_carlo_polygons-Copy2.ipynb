# %%
import matplotlib.pyplot as plt
import numpy as np
PI = np.pi
atol = 1e-15
number_of_points = 10
from figures import Point, Line, Polygon
from utils import get_fig_base, calculate_area_monte_carlo

a = Point('A', 0.25, 0.9)
b = Point('B', 0.75, 0.84)
c = Point('C', 0.44, 0.78)
d = Point('D', 0.61, 0.38)
e = Point('E', 0.62, 0.82)
poly = Polygon([a,b,c,d,e])

fig, ax =  get_fig_base()

poly.draw(fig, ax)
poly.is_convex()
# Out:
# D=(0.61, 0.38) A=(0.25, 0.9) 124.69515353123397
# D=(0.61, 0.38) B=(0.75, 0.84) 73.07248693585295
# D=(0.61, 0.38) C=(0.44, 0.78) 113.02549200852803
# D=(0.61, 0.38) D=(0.61, 0.38) 0.0
# D=(0.61, 0.38) E=(0.62, 0.82) 88.69804732742112
# D=(0.61, 0.38) B=(0.75, 0.84) 73.07248693585295
# D=(0.61, 0.38) E=(0.62, 0.82) 88.69804732742112
# D=(0.61, 0.38) C=(0.44, 0.78) 113.02549200852803
# D=(0.61, 0.38) A=(0.25, 0.9) 124.69515353123397
# [ 73.07248694  88.69804733 113.02549201 124.69515353]
# [15.62556039 24.32744468 11.66966152]
# B=(0.75, 0.84) E=(0.62, 0.82) -171.2538377374448
# B=(0.75, 0.84) C=(0.44, 0.78) -169.04593735660168
# B=(0.75, 0.84) A=(0.25, 0.9) 173.15722658736905
# [-171.25383774 -169.04593736  173.15722659]
# [  2.20790038 342.20316394]
# E=(0.62, 0.82) C=(0.44, 0.78) -167.4711922908485
# E=(0.62, 0.82) A=(0.25, 0.9) 167.79953127261922
# [-167.47119229  167.79953127]
# [335.27072356]
# C=(0.44, 0.78) A=(0.25, 0.9) 147.72435568542238
# [147.72435569]
# []
# []
# []
# True

# %%
edges=poly.edges
for i in range(len(edges)-1):
    print("\n\n", edges[i], edges[i+1])
    print(np.arctan(edges[i].slope)*180/PI,   np.arctan(edges[i+1].slope)*180/PI)
    print(np.arctan(edges[i].slope)*180/PI-np.arctan(edges[i+1].slope)*180/PI)
# Out:
#  line_DB line_BE
# 73.07248693585295 4.398705354995536
# 68.67378158085741
#
#
#  line_BE line_EC
# 4.398705354995536 15.524110996754239
# -11.125405641758704
#
#
#  line_EC line_CA
# 15.524110996754239 -32.27564431457763
# 47.79975531133187
#
#
#  line_CA line_AD
# -32.27564431457763 -55.30484646876604
# 23.029202154188404

# %%
for e in poly.edges:
    print(e, e.slope, np.arctan(e.slope), np.arctan(e.slope)*180/PI)
# Out:
# line_DB 3.285714285714285 1.2753554896511765 73.07248693585295
# line_BE 0.07692307692307698 0.0767718912697781 4.398705354995536
# line_EC 0.2777777777777774 0.2709468503384202 15.524110996754239
# line_CA -0.631578947368421 -0.5633162614919681 -32.27564431457763
# line_AD -1.4444444444444446 -0.9652516631899266 -55.30484646876604

# %%
fig, ax =  get_fig_base()

poly.draw(fig, ax)
poly.is_convex()
# Out:
# D=(0.61, 0.38) A=(0.25, 0.9) 124.69515353123397
# D=(0.61, 0.38) B=(0.75, 0.84) 73.07248693585295
# D=(0.61, 0.38) C=(0.44, 0.78) 113.02549200852803
# D=(0.61, 0.38) D=(0.61, 0.38) 0.0
# D=(0.61, 0.38) E=(0.62, 0.83) 88.72696997994329
# D=(0.61, 0.38) B=(0.75, 0.84) 73.07248693585295
# D=(0.61, 0.38) E=(0.62, 0.83) 88.72696997994329
# D=(0.61, 0.38) C=(0.44, 0.78) 113.02549200852803
# D=(0.61, 0.38) A=(0.25, 0.9) 124.69515353123397
# [ 73.07248694  88.72696998 113.02549201 124.69515353]
# [15.65448304 24.29852203 11.66966152]
# B=(0.75, 0.84) E=(0.62, 0.83) -175.6012946450045
# B=(0.75, 0.84) C=(0.44, 0.78) -169.04593735660168
# B=(0.75, 0.84) A=(0.25, 0.9) 173.15722658736905
# [-175.60129465 -169.04593736  173.15722659]
# [  6.55535729 342.20316394]
# E=(0.62, 0.83) C=(0.44, 0.78) -164.47588900324578
# E=(0.62, 0.83) A=(0.25, 0.9) 169.28687697720895
# [-164.475889    169.28687698]
# [333.76276598]
# C=(0.44, 0.78) A=(0.25, 0.9) 147.72435568542238
# [147.72435569]
# []
# []
# []
# True

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %% [markdown]
# ## New method

# %%
number_of_samples = 100

for i in range(number_of_samples):    
    print(i)
    n = np.random.randint(3, 8)
    new_coordinates = np.random.uniform(size = (n, 2))
    new_points = [Point("p" + str(i+1), x,y) for i, (x,y) in enumerate(new_coordinates)]
    
    fig, ax = get_fig_base()
    polygon = Polygon(new_points)
    polygon.draw(fig, ax)

    if polygon.is_convex():
        #calculate_area_monte_carlo(figure=polygon, number_of_points=1000, draw_final_result=True)
        fig.savefig(f'graphics/fig_{i}.png')

# %%
stop

# %%
stop

# %%
number_of_points=1000

# %% [markdown]
# a = Point('A', 1, 0)
# b = Point('B', 0, 0)
# c = Point('C', 0.5, 0.2)
# d = Point('D', 0.2, 0.9)
# f = Point('F', 0.2, 0.2)
# e = Point('E', 0.7, 0.6)
# poly = Polygon([a,b,c])
#
#
# fig, ax =  get_fig_base()
#
#
# color = ['pink', 'blue', 'green', 'orange', 'magenta', 'gray']
#
# coordinates = np.random.uniform(size=(number_of_points, 2))
# points = [Point('', x, y) for i, (x,y) in enumerate(coordinates)]
#
#
# left_border = min([p.x for p in poly.vertices])
# right_border = max([p.x for p in poly.vertices])
# bottom_border = min([p.y for p in poly.vertices])
# top_border = max([p.y for p in poly.vertices])
#
# poly.draw(fig, ax)
#
# for pp in points:
#     drawn = False
#     counter = 0
#
#
#     if left_border<pp.x<right_border and bottom_border<pp.y<top_border:
#         for i, edge in enumerate(poly.edges):
#
#             if edge.is_point_in_line(pp):
#                 pp.draw_point(fig, ax, color='red')
#                 break
#
#             line = edge.get_line_to_point(pp)
#
#             if edge.is_point_in_line(line.ending_point):
#                 counter +=1
#
#                 inner_counter = 0
#
#                 for interior_edge in poly.edges:
#                     #innner_counter+=1
#                     CP = line.get_crossing_point(interior_edge)
#
#                     if interior_edge.is_point_in_line(CP) and line.is_point_in_line(CP) and \
#                             line.starting_point != CP and line.ending_point!= CP:
#                         inner_counter+=1
#
#                 if inner_counter%2==1:
#                     pp.draw_point(fig, ax, color='brown')
#                     drawn = True
#
#         if drawn==False:
#
#
#             if counter == 1:
#                 pp.draw_point(fig, ax, color='orange')
#             else:
#                 pp.draw_point(fig, ax, color='green')
#     else:
#         pp.draw_point(fig, ax, color='magenta')

# %%
calculate_area_monte_carlo(figure=poly, number_of_points=1000, draw_final_result=True)

# %%
calculate_area_monte_carlo(figure=poly, number_of_points=1000, draw_final_result=True)

# %% [markdown]
# #
